# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install tensorflow opencv-python matplotlib

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to the "healthy" coral images
healthy_dir = '/content/drive/MyDrive/ocean health/healthy_corals'  # Change path if needed

# List of image file names
image_files = os.listdir(healthy_dir)

# Display the first 5 healthy coral images
for i in range(5):
    img_path = os.path.join(healthy_dir, image_files[i])
    img = mpimg.imread(img_path)
    plt.imshow(img)
    plt.title(f"Healthy Coral - {image_files[i]}")
    plt.axis('off')
    plt.show()

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
# 📁 Change this to your dataset path
dataset_path = "path_to_dataset/Coral_Health"
print(dataset_path)
# Out:
# path_to_dataset/Coral_Health

# %%
# 2. CNN Model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import tensorflow as tf

# Load data
data = tf.keras.utils.image_dataset_from_directory("/content/drive/MyDrive/ocean health", image_size=(64, 64), batch_size=32)

# Build model
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.Conv2D(8, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile and train
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(data, epochs=3)
# Out:
# Found 923 files belonging to 2 classes.
# Epoch 1/3
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 548ms/step - accuracy: 0.5836 - loss: 0.6862
# Epoch 2/3
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.7363 - loss: 0.5710
# Epoch 3/3
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.7266 - loss: 0.5290
